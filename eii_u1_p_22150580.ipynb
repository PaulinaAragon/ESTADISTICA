# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulinaAragon/ESTADISTICA/blob/main/eii_u1_p_22150580.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Metodología**
#
# *Introducción*
#
# En este trabajo se analiza si los años de experiencia influyen en el salario usando un modelo matemático llamado regresión lineal. Se hacen cálculos para ver qué tan fuerte es la relación entre estas dos cosas y si realmente están conectadas. Además, se revisa si el modelo cumple ciertas reglas para asegurarnos de que los resultados sean confiables.
#
# *Planteamiento de Hipótesis*
#
# Para evaluar la relación entre los años de experiencia y el salario, se establecen las siguientes hipótesis:
#
# Hipótesis para el Modelo de Regresión Lineal
# Hipótesis Nula (𝐻0): No existe una relación significativa entre los años de experiencia y el salario, es decir, la pendiente de la regresión es igual a cero (𝛽1=0).
#
# Hipótesis Alternativa (𝐻1): Existe una relación significativa entre los años de experiencia y el salario, es decir, la pendiente de la regresión es distinta de cero (𝛽1≠0).
#
# Hipótesis para la Prueba de Normalidad (Shapiro-Wilk)
#
# Hipótesis Nula (𝐻0): Los residuos del modelo siguen una distribución normal.
#
# Hipótesis Alternativa (𝐻1): Los residuos del modelo no siguen una distribución normal.
#
# Hipótesis para la Prueba de Homocedasticidad (Breusch-Pagan)
#
# Hipótesis Nula (𝐻0): La varianza de los residuos es constante (homocedasticidad).
#
# Hipótesis Alternativa (𝐻1): La varianza de los residuos no es constante (heterocedasticidad).
#
# *Tipo de Estudio*
#
# Este estudio es de tipo cuantitativo y exploratorio, ya que busca analizar la relación entre la experiencia laboral y el salario mediante herramientas estadísticas.
#
# *Marco Teorico*
#
# La regresión lineal es un método estadístico utilizado para modelar la relación entre una variable dependiente 𝑌 y una variable independiente 𝑋. En este caso, se analiza cómo los años de experiencia afectan el salario.
#
# El modelo de regresión lineal simple se expresa como: 𝑌=𝛽0 + 𝛽1𝑋 + 𝜀
#
# Donde:
#
# Y es el salario.
#
# X representa los años de experiencia.
#
# 𝛽0 es la ordenada al origen.
#
# 𝛽1 es la pendiente, que indica el cambio esperado en el salario por cada año adicional de experiencia.
#
# ε es el error aleatorio.
#
# Para evaluar la calidad del modelo, se calculan el coeficiente de correlación y el coeficiente de determinación, que indican qué tan bien la variable independiente explica la variación en la variable dependiente. Además, se realizan pruebas estadísticas para validar los supuestos del modelo, como normalidad de los residuos y homocedasticidad.
#
# *Metogologia*
#
# Obtención de Datos:
#
# Se utilizó un conjunto de datos que relaciona los años de experiencia con el salario. Se eliminaron registros con valores faltantes.
#
#
# Análisis Exploratorio:
#
# Se realizó un gráfico de dispersión para visualizar la relación entre ambas variables.
#
# Ajuste del Modelo:
#
# Se aplicó una regresión lineal simple para encontrar la ecuación que mejor representa la relación entre experiencia y salario.
#
# Coeficiente de correlación:
#
# Mide la fuerza y dirección de la relación entre la experiencia y el salario.
#
# Coeficiente de determinación:
#
# Indica el porcentaje de variabilidad en el salario que puede explicarse por los años de experiencia.
#
# Evaluacion del modelo:
#
# Se calcularon los coeficientes de correlación y determinación para medir la fuerza de la relación.
#
#
# Se obtuvo un intervalo de confianza del 95% para la pendiente.
#
#
# Se realizó un análisis de varianza (ANOVA) para evaluar la significancia del modelo.
#
# Verificacion de Supuestos:
#
# Se aplicó la prueba de Shapiro-Wilk para evaluar la normalidad de los residuos.
#
# Se utilizó la prueba de Breusch-Pagan para verificar la homocedasticidad.
#
# *Resultados*
#
# Gráfico de dispersión: Se observó una relación positiva entre los años de experiencia y el salario.
#
# Ecuación de regresión: La ecuación ajustada fue 𝑌=𝑏0+𝑏1X, donde 𝑏0 y 𝑏1 fueron determinados a partir de los datos.
#
# Coeficiente de correlación: Se obtuvo un valor que indica una asociación fuerte entre las variables.
#
# Coeficiente de determinación: El modelo explica un alto porcentaje de la variabilidad del salario.
#
# Prueba de hipótesis: Se rechazó la hipótesis nula, confirmando que la experiencia influye significativamente en el salario.
#
#
# Validación del modelo:
#
# La prueba de normalidad de Shapiro-Wilk mostró que los residuos siguen una distribución aproximadamente normal.
#
# La prueba de Breusch-Pagan indicó que la varianza de los residuos es constante, validando la homocedasticidad del modelo.
#
# *Conclusión*
#
# Los resultados muestran que, en general, tener más años de experiencia sí ayuda a ganar un mejor salario. El modelo confirma que hay una relación entre ambas cosas y que los cálculos son correctos. Sin embargo, hay otros factores, como la educación y el tipo de trabajo, que también pueden influir en el salario, por lo que sería bueno analizarlos en estudios futuros.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/PaulinaAragon/ESTADISTICA/refs/heads/main/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/PaulinaAragon/ESTADISTICA/refs/heads/main/Salary_Data.csv')
# eliminar registros  cpn valores faltantes
df.dropna(inplace=True)

X = df["YearsExperience"] # Variable independiente
Y = df["Salary"] # Variable dependiente

# b) Realiza un gráfico con la dispersión y la recta de regresión ajustada.
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'black')
plt.xlabel('YearsExperience') #nombrar eje x
plt.ylabel('Salary') #nombrar eje y
ax=plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# Recta de regresion lineal
import statsmodels.api as sm
X_constante = sm.add_constant(X)
modelo = sm.OLS(Y, X_constante).fit()
b0, b1 = modelo.params
Fun = lambda X: b0 + b1 * X
Yc = Fun(X)
plt.plot(X, Yc, color = 'red', linestyle = '--')

# c) Calcula el coeficiente de correlación y el coeficiente de determinación e interpreta los resultados.
from scipy.stats import pearsonr
r,_ = pearsonr(X, Y)
print(f'coeficiente de correlacion: {r: 0.4f}\n')
print(f'coeficiente de determinacion: {r ** 2: 0.4f}\n')

# d) Obtén un intervalo de confianza de 95% para la pendiente e interpreta el resultado. Respalda tu conclusión usando ANOVA.
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}')

# Tabla ANOVA
from statsmodels.formula.api import ols
# Y ~ X
modelo_2 = ols('YearsExperience ~ Salary', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2)
print(tabla_anova)

# e) Verifica los supuestos.
residuales = modelo.resid
plt.figure()
plt.scatter(X, residuales, color = 'black')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.axhline(y = 0, color = 'red', linestyle = '--')

from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f' valor_p Test de shapiro: {valor_p_sh: 0.4f}\n')

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, X_constante)
print(f'Valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# coeficiente de correlacion:  0.9782
#
# coeficiente de determinacion:  0.9570
#
# intervalo de confianza para b1 de  95%
#  8674.1187 < b1 <  10225.8059
#             df      sum_sq     mean_sq           F        PR(>F)
# Salary     1.0  223.501695  223.501695  622.507203  1.143068e-20
# Residual  28.0   10.052972    0.359035         NaN           NaN
#  valor_p Test de shapiro:  0.1952
#
# Valor_p de Breusch-Pagan:  0.5276
